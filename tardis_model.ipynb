# %%
import sklearn as sk
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.neighbors import KNeighborsRegressor

df = pd.read_csv("cleaned_dataset.csv")
column_use = ['Number of scheduled trains', 'Month', 'Departure station',
                'Arrival station', 'Average journey time', 'Service']
X = df[column_use]
X = pd.get_dummies(X, columns=['Departure station', 'Month', 'Arrival '
                'station', 'Service'], drop_first=True)
y = df['Average delay of all trains at arrival']

X_train, X_test, y_train, y_test = sk.model_selection.train_test_split(X, y, test_size=0.2, random_state=12)

# %%
model_rf = RandomForestRegressor(n_estimators=100, random_state=12)
model_rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=12)

# %%
model_lr = LinearRegression()
model_lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model_knr = KNeighborsRegressor(n_neighbors=5)
model_knr.fit(X_train, y_train)
# Out:
# KNeighborsRegressor()

# %% [markdown]
# Model evaluation

# %%
model_rdg = Ridge()
model_rdg.fit(X_train, y_train)
# Out:
# Ridge()

# %%
model_lso = Lasso()
model_lso.fit(X_train, y_train)
# Out:
# Lasso()

# %%
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error

y_pred_lin = model_lr.predict(X_test)
y_pred_rf = model_rf.predict(X_test)
y_pred_knr = model_knr.predict(X_test)
y_pred_rdg = model_rdg.predict(X_test)
y_pred_lso = model_lso.predict(X_test)

print("Linear regression evaluation")
print(f"MAE\t: {mean_absolute_error(y_test, y_pred_lin):.2f}")
print(f"R2\t: {r2_score(y_test, y_pred_lin):.2f}")
print(f"MSE\t: {mean_squared_error(y_test, y_pred_lin):.2f}")

print("Random forest regressor evaluation")
print(f"MAE\t: {mean_absolute_error(y_test, y_pred_rf):.2f}")
print(f"R2\t: {r2_score(y_test, y_pred_rf):.2f}")
print(f"MSE\t: {mean_squared_error(y_test, y_pred_rf):.2f}")

print("Kn neighbors regressor evaluation")
print(f"MAE\t: {mean_absolute_error(y_test, y_pred_knr):.2f}")
print(f"R2\t: {r2_score(y_test, y_pred_knr):.2f}")
print(f"MSE\t: {mean_squared_error(y_test, y_pred_knr):.2f}")

print("Ridge evaluation")
print(f"MAE\t: {mean_absolute_error(y_test, y_pred_rdg):.2f}")
print(f"R2\t: {r2_score(y_test, y_pred_rdg):.2f}")
print(f"MSE\t: {mean_squared_error(y_test, y_pred_rdg):.2f}")

print("Lasso evaluation")
print(f"MAE\t: {mean_absolute_error(y_test, y_pred_lso):.2f}")
print(f"R2\t: {r2_score(y_test, y_pred_lso):.2f}")
print(f"MSE\t: {mean_squared_error(y_test, y_pred_lso):.2f}")
# Out:
# Linear regression evaluation
# MAE	: 2.45
# R2	: 0.30
# MSE	: 17.21
# Random forest regressor evaluation
# MAE	: 2.47
# R2	: 0.27
# MSE	: 18.04
# Kn neighbors regressor evaluation
# MAE	: 2.82
# R2	: 0.15
# MSE	: 21.05
# Ridge evaluation
# MAE	: 2.44
# R2	: 0.30
# MSE	: 17.23
# Lasso evaluation
# MAE	: 2.88
# R2	: 0.13
# MSE	: 21.45

# %% [markdown]
# ## Comment les modeles de predictions fonctionnent t-ils ?

# %% [markdown]
# Linear regressor:
# The prediction model assigns a weight to each column it receives, which
# allows it to prioritize certain values over others values.
#
# Random forest regressor:
# It creates decision trees (n_estimators) that allow it to make
# choices based on the
# different input values.
#
# Kn neighbors regressor:
# It examines the n cases that most closely resemble it and estimates based on what it finds.
#
# Ridge regressor:
# Copies the functionality of the linear regressor but assigns less weight to the
# values than the linear regressor.
#
# Lasso regressor:
# It does not use columns that it declares unnecessary and uses the
# column weighting system.

# %% [markdown]
# ## Best prediction model
#
# The best model in relation to the results obtained remains the ridge regressor
# model, because this model allows us to give weight to the information that is
#  actually useful and therefore to better interpret the information, and don't
#   give to much power to column.

# %% [markdown]
# model.joblib creation to save the model in a file to use it in the dashboard.

# %%
import joblib

joblib.dump(model_rdg, 'model.joblib')
# Out:
# ['model.joblib']
